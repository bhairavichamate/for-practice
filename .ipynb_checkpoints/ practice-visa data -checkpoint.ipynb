# %% [markdown]
# Step-1
#
# import packages

# %%
# 08-12-2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# step-2
#
# Read the data

# %%
file_path=r"C:\Users\bhair\Downloads\Visadataset (1).csv"
visa_nd=pd.read_csv(file_path)
visa_nd
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# Shape

# %%
visa_nd.shape
# Out:
# (25480, 12)

# %%
type(visa_nd)
# Out:
# pandas.core.frame.DataFrame

# %%
print('the number of row are:',visa_df.shape[0])
print('the number of column are :',visa_df.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 print('the number of row are:',visa_df.shape[0])
#       2 print('the number of column are :',visa_df.shape[1])
#
# NameError: name 'visa_df' is not defined

# %% [markdown]
# size
#
# not callable means brackets are not required

# %%
visa_nd.size
# Out:
# 305760

# %%
visa_nd.shape[0]*visa_nd.shape[1]
# Out:
# 305760

# %%
visa_nd.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_nd.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
visa_nd.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')>

# %%
visa_nd.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_nd.dtypes)
# Out:
# pandas.core.series.Series

# %%
visa_nd.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_nd.dtypes.index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_nd.dtypes.keys
# Out:
# <bound method Series.keys of case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object>

# %%
list1=[1,2,3,4]
list1
[1,2,3,4]+[5,6,7]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
visa_nd.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
type(visa_nd.dtypes.values)
# Out:
# numpy.ndarray

# %%
list1=[1,2,3,4]
list1
# Out:
# [1, 2, 3, 4]

# %%
np.array([1,2,3])+np.array([4,5,6])
# Out:
# array([5, 7, 9])

# %%
visa_nd
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# task-1
#
# sepearte numerical columns and categorical columnss sepeareatly

# %%
cat=[]
num=[]
data_types=visa_nd.dtypes
dict1=dict(data_types)
for i in dict1:
    if dict1[i]=='O':
        cat.append(i)
    else:
        num.append(i)
        
# cat =[i for i in dict(data_types) if dict(data_types)[i]=='object']
# num=[i for i in dict(data_types)if dict(data_Types)[i]!='object']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# head

# %% [markdown]
# - top 5 values

# %%
# dataFrame name=visa-nd
visa_nd.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_nd.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_nd.head(0)
# Out:
# Empty DataFrame
# Columns: [case_id, continent, education_of_employee, has_job_experience, requires_job_training, no_of_employees, yr_of_estab, region_of_employment, prevailing_wage, unit_of_wage, full_time_position, case_status]
# Index: []

# %% [markdown]
# tail

# %%
visa_nd.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_nd.tail(4)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25476            Northeast        279174.79         Year                  Y
# 25477                South        146298.85         Year                  N
# 25478                 West         86154.77         Year                  Y
# ...

# %%
list1=[1,2,3]
visa_nd.iloc[list1]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied

# %% [markdown]
# columns

# %%
visa_nd.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(visa_nd)
# Out:
# 25480

# %% [markdown]
# take

# %%
visa_nd.take([101,102,103])

# take only specific index values
# inside take , one more argument is axis
# the defoult value of axis :0
# axis=0 means rows
# which means 101,102,103 row will come
# axis=1 means columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 101  EZYV102      Asia              Master's                  Y
# 102  EZYV103      Asia            Bachelor's                  Y
# 103  EZYV104      Asia             Doctorate                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 101                     N              334         2007              Midwest
# 102                     N              224         2008              Midwest
# 103                     N              367         1982                 West
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 101         43421.88         Year                  Y   Certified
# 102         80253.78         Year                  Y   Certified
# 103        115235.95         Year                  Y   Certified

# %%
visa_nd.take([100,200,300],axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 visa_nd.take([100,200,300],axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3703, in NDFrame.take(self, indices, axis, is_copy, **kwargs)
#    3699 nv.validate_take((), kwargs)
#    3701 self._consolidate_inplace()
# -> 3703 new_data = self._mgr.take(
#    3704     indices, axis=self._get_block_manager_axis(axis), verify=True
#    3705 )
#    3706 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:897, in BaseBlockManager.take(self, indexer, axis, verify)
#     890 indexer = (
#     891     np.arange(indexer.start, indexer.stop, indexer.step, dtype=np.intp)
#     892     if isinstance(indexer, slice)
#     893     else np.asanyarray(indexer, dtype=np.intp)
#     894 )
# ...

# %%
visa_nd.take([1,2,3])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied

# %%
visa_nd.take([1,2,3],axis=1)
# Out:
#       continent education_of_employee has_job_experience
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
# [25480 rows x 3 columns]

# %% [markdown]
# task-2
#
# I want 150,300,450 rows from 5,8,12 by using take

# %%
d1=visa_nd.take([5,8,11],axis=1)
d1.take([150,300,450])

# python index start with zero
# we have total 12 columns
# but in python 12th columns index is 11
# Out:
#      no_of_employees  prevailing_wage case_status
# 150            50351         529.1105      Denied
# 300             3268      101371.2100   Certified
# 450             1543       78402.7200      Denied

# %%
visa_nd.take([5,8,11],axis=1).take([150,300,450])
# Out:
#      no_of_employees  prevailing_wage case_status
# 150            50351         529.1105      Denied
# 300             3268      101371.2100   Certified
# 450             1543       78402.7200      Denied

# %% [markdown]
# $loc-iloc$

# %%
# data.illoc(<row>,<columns>)
# data.iloc(start:end,start:end)
# assime that I want 20:25 rows
# 3:6 columns

# %%
visa_nd.iloc[20:25,3:6]
# Out:
#    has_job_experience requires_job_training  no_of_employees
# 20                  N                     N              880
# 21                  Y                     N             1706
# 22                  Y                     N             2878
# 23                  N                     N             1517
# 24                  Y                     N              241

# %%
visa_nd.iloc[20:25] # all the columns
# Out:
#    case_id      continent education_of_employee has_job_experience  \
# 20  EZYV21           Asia              Master's                  N
# 21  EZYV22  North America              Master's                  Y
# 22  EZYV23           Asia              Master's                  Y
# 23  EZYV24  North America           High School                  N
# 24  EZYV25         Europe             Doctorate                  Y
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 20                     N              880         2008                 West
# 21                     N             1706         2013              Midwest
# 22                     N             2878         1968                 West
# 23                     N             1517         1884              Midwest
# 24                     N              241         1981              Midwest
#
#     prevailing_wage unit_of_wage full_time_position case_status
# ...

# %%
list1=[100,200,300]
visa_nd.iloc[list1]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
rows=[100,200,300]
columns=[5,8,11]
visa_nd.iloc[rows,columns]
# Out:
#      no_of_employees  prevailing_wage case_status
# 100             2227         28243.79   Certified
# 200             3282         74441.11   Certified
# 300             3268        101371.21   Certified

# %%
visa_nd.size
# Out:
# 305760

# %%
rows=[13,12,23]
columns=[9,7,8]
visa_nd.iloc[rows,columns]

#  visa_nd.take(columns,axis=1).take(rows)
# Out:
#    unit_of_wage region_of_employment  prevailing_wage
# 13         Year              Midwest        107196.03
# 12         Year            Northeast         28663.05
# 23         Year              Midwest         90108.38

# %%
visa_nd
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# case status:100,200 rows
rows=[100,200]
columns=[11]
visa_nd.iloc[rows,columns]
# Out:
#     case_status
# 100   Certified
# 200   Certified

# %%
visa_nd.iloc[rows,[11]] # 
visa_nd.loc[rows,['case_status']]
# Out:
#     case_status
# 100   Certified
# 200   Certified

# %%
visa_nd.columns[:3]
# Out:
# Index(['case_id', 'continent', 'education_of_employee'], dtype='object')

# %%
visa_nd.loc[[200],['case_id', 'continent', 'education_of_employee']]
visa_nd.iloc[[200],[1,2,3]]
# Out:
#     continent education_of_employee has_job_experience
# 200      Asia             Doctorate                  Y

# %% [markdown]
# info

# %%
visa_nd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# isnull

# %%
visa_nd.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_nd.isnull().sum()

#this will provide 
#column wise missing values/ null values
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_nd.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...
